# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-RFLopes/python_sis_26_2/blob/laura_lopes/laura_lopes_aula_02_exercicio_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite o seu nome ")
ordem = input("Digite a sua ordem ")
altura = float(input("Digite a sua altura "))
manipulador_fluxos = bool(input("Manipuladoer de fluxos? digite: Sim/Não "))


print("\n Fixa de personagem:")
print("\nNome: " + nome)
print("Ordem: " + ordem)
print("altura:"  + str(altura))
print("Manipulador de fluxos:"+ str(manipulador_fluxos))
# Out:
# Digite o seu nome Shallan
# Digite a sua ordem Teceluz
# Digite a sua altura 1.60
# Manipuladoer de fluxos? digite: Sim/Não Sim
#
#  Fixa de personagem:
#
# Nome: Shallan
# Ordem: Teceluz
# altura:1.6
# Manipulador de fluxos:True
