# %% [markdown]
# <a href="https://colab.research.google.com/github/moa-hub470/pythondemoacir_sis_26_2/blob/moacir_oliveira/aula01/moacir_oliveira_ambienta%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import this

# %%
import antigravity

# %%
from __future__ import braces
# Out:
#   File "/tmp/ipykernel_3117/3905450354.py", line 1
#     from __future__ import braces
#                            ^
# SyntaxError: not a chance

# %%
print ("Hello World, meu Nome é Moacir Oliveira e estou aprendendo Python!!!")
print ("Bye World")
# Out:
# Hello World, meu Nome é Moacir Oliveira e estou aprendendo Python!!!

# %%
#print ("Hello World")
print ("Bye World")
# Out:
# Bye World

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
quantidade_caixas = 4
macas_por_caixa = 12
total_macas = quantidade_caixas * macas_por_caixa

total_cavaleiros = 5
macas_por_cavaleiro = total_macas // total_cavaleiros

portao_aberto = (macas_por_cavaleiro > 8)

print("Quantidade de maçãs por cavaleiro:")
print(macas_por_cavaleiro)

print("O portão do castelo se abriu?")
print(portao_aberto)
# Out:
# Quantidade de maçãs por cavaleiro:
# 9
# O portão do castelo se abriu?
# True

# %%
quantidade_caixas = 4
macas_por_caixa = 12
total_macas = quantidade_caixas * macas_por_caixa

total_cavaleiros = 6
macas_por_cavaleiro = total_macas // total_cavaleiros

portao_aberto = (macas_por_cavaleiro > 8)

print("Quantidade de maçãs por cavaleiro:")
print(macas_por_cavaleiro)

print("O portão do castelo se abriu?")
print(portao_aberto)
# Out:
# Quantidade de maçãs por cavaleiro:
# 8
# O portão do castelo se abriu?
# False
