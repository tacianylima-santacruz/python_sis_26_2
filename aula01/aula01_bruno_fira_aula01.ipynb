# %% [markdown]
# <a href="https://colab.research.google.com/github/brunokoskki/python_sis_26_2/blob/bruno_firakoski/aula01/aula01_bruno_fira_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 01**
# Montando a ficha de um personagem

# %%
#Character test:

name = "Tony Stark"   #string: Seria o nick-name, que identifica quem é o persongaem
age = 38              #int: Para saber se o personagem é criança, adulto ou velho
height = 1.73         #float: Para identifica se ele é anão/default/gigante
armor = True          #boolean: Quando True, tony está com a armadura do homem de ferro

my_character = [name, age, height, armor]
print(my_character)

##classe que irá inserir o personagem Tony Stark
class TonyStark:
# Out:
#   File "/tmp/ipykernel_1728/3918461097.py", line 12
#     class TonyStark:
#                     ^
# SyntaxError: incomplete input
