# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-RFLopes/python_sis_26_2/blob/laura_lopes/aula01/laura_lopes_aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Kaladin"
idade = 19
altura = 1.80
manipulador_fluxo = True
print(f'Nome: {nome}')
print(f'Idade: {idade}')
print(f'Altura: {altura}')
print(f'Manipuladorde fluxos? {manipulador_fluxo}')
# Out:
# Nome: Kaladin
# Idade: 19
# Altura: 1.8
# Manipuladorde fluxos? True
