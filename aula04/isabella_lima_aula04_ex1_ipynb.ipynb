# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/aula04/isabella_lima_aula04_ex1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 04 | EXERCÍCIO | OPERADORES RELACIONAIS

# Crie duas variáveis: atribuindo valores numéricos a cada uma delas.
jogador1 = 100
jogador2 = 150

# Utilizando a função print(), exiba na tela o resultado de todas as seis operações
# relacionais estudadas, comparando a pontuação do jogador 1 com a do jogador 2
# Você deve escrever uma frase explicativa antes de cada resultado para identificar o que está sendo comparado.
print("Jogador 1 é igual ao Jogador 2?", jogador1 == jogador2) # Igual
print("Jogador 1 é diferente do Jogador 2?", jogador1 != jogador2)  # Diferente
print("Jogador 1 é maior que o Jogador 2?", jogador1 > jogador2) # Maior
print("Jogador 1 é menor que o Jogador 2?", jogador1 < jogador2) # Menor
print("Jogador 1 é maior ou igual ao Jogador 2?", jogador1 >= jogador2) # Maior ou Igual
print("Jogador 1 é menor ou igual ao Jogador 2?", jogador1 <= jogador2) # Menor ou Igual
# Out:
# Jogador 1 é igual ao Jogador 2? False
# Jogador 1 é diferente do Jogador 2? True
# Jogador 1 é maior que o Jogador 2? False
# Jogador 1 é menor que o Jogador 2? True
# Jogador 1 é maior ou igual ao Jogador 2? False
# Jogador 1 é menor ou igual ao Jogador 2? True
