# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/aula04/isabella_lima_aula04_ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 04 | EXERCÍCIO 4 | A JORNADA DO PERSONAGEM (OPERADORES E CONDICIONAIS)

# Cálculos e Variáveis: Crie pelo menos 3 variáveis que envolvam operações aritméticas
vida_dean = 0
vida_monstro = 0
municao = 0

# Tomada de Decisão (if / else): Baseado nos resultados desses cálculos,
# crie 3 testes condicionais para verificar o estado do seu personagem.
# Mostre o que aconteceu na história usando o print().
if vida_dean > 0:
    print("Dean continua vivo!")
else:
    print("Dean morreu :( !")


if vida_monstro <= 0:
    print("O monstro foi derrotado!")
else:
    print("O monstro continua vivo!")


if municao > 0:
    print("Dean ainda tem munição!")
else:
    print("A munição acabou!")
# Out:
# Dean morreu :( !
# O monstro foi derrotado!
# A munição acabou!
