# %% [markdown]
# <a href="https://colab.research.google.com/github/kkauandinizz/python_sis_26_2/blob/kauan_diniz/kauan_diniz_aula_02_exercicio_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from types import MappingProxyType
personagem_nome = "Gelado"
personagem_nivel = 67
gelo_precisao = 0.67
arma_equipada = True

print(type(personagem_nome),personagem_nome)
print(type(personagem_nivel),personagem_nivel)
print(type(gelo_precisao),gelo_precisao)
print(type(arma_equipada),arma_equipada)

personagem_altura = 1.80
personagem_peso = 60
personagem_cor_olhos = "Castanhos"
personagem_cabelo = "Preto"


print(type(personagem_altura), personagem_altura)
print(type(personagem_peso), personagem_peso)
print(type(personagem_cor_olhos), personagem_cor_olhos)
print(type(personagem_cabelo), personagem_cabelo)

class personagem:


    """

personagem_nome armazena o nome do personagem.
personagem_nivel armazena o nível do personagem.
arco_precisao armazena a precisão do arco.
arma_equipada informa se o personagem está usando uma arma.

Depois, o código utiliza type() para mostrar o tipo de dado
de cada variável e print() para mostrar seus respectivos valores.


    """

help(personagem)
# Out:
# <class 'str'> Gelado
# <class 'int'> 67
# <class 'float'> 0.67
# <class 'bool'> True
# <class 'float'> 1.8
# <class 'int'> 60
# <class 'str'> Castanhos
# <class 'str'> Preto
# Help on class personagem in module __main__:
#
# class personagem(builtins.object)
#  |  personagem_nome armazena o nome do personagem.
#  |  personagem_nivel armazena o nível do personagem.
#  |  arco_precisao armazena a precisão do arco.
#  |  arma_equipada informa se o personagem está usando uma arma.
#  |
#  |  Depois, o código utiliza type() para mostrar o tipo de dado
#  |  de cada variável e print() para mostrar seus respectivos valores.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
personagem_nome = input("Digite o nome: ")
personagem_nivel = int(input("Digite o nível: "))
personagem_idade = int(input("Digite a idade: "))
personagem_altura = float(input("Digite a altura: "))
personagem_peso = float(input("Digite o peso: "))
personagem_cabelo = input("Digite a cor do cabelo: ")
personagem_olhos = input("Digite a cor dos olhos: ")
personagem_forca = int(input("Digite a força: "))
personagem_velocidade = int(input("Digite a velocidade: "))

print(type(personagem_nome), personagem_nome)
print(type(personagem_nivel), personagem_nivel)
print(type(personagem_idade), personagem_idade)
print(type(personagem_altura), personagem_altura)
print(type(personagem_peso), personagem_peso)
print(type(personagem_cabelo), personagem_cabelo)
print(type(personagem_olhos), personagem_olhos)
print(type(personagem_forca), personagem_forca)
print(type(personagem_velocidade), personagem_velocidade)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3628/2551419097.py in <cell line: 0>()
# ----> 1 personagem_nome = input("Digite o nome: ")
#       2 personagem_nivel = int(input("Digite o nível: "))
#       3 personagem_idade = int(input("Digite a idade: "))
#       4 personagem_altura = float(input("Digite a altura: "))
#       5 personagem_peso = float(input("Digite o peso: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
