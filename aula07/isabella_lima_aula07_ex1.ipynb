# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/aula07/isabella_lima_aula07_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 07 | EXERCÍCIO 1 | Caça aos Bugs (Traceback)

# nome_heroi = "Batman"
# print("O herói que vai salvar a cidade é o " + nome_heroi_cidade)
nome_heroi = "Batman"
print("O herói que vai salvar a cidade é o " + nome_heroi) # Correção: foi utilizado o nome correto da variável.

print("-----------------------------------------------------------------------")

# idade_pet = 5
# mensagem = "A idade do meu cachorro é " + idade_pet + " anos."
# print(mensagem)
idade_pet = 5
mensagem = "A idade do meu cachorro é " + str(idade_pet) + " anos." # Correção: idade_pet foi convertida para string para permitir a concatenação.
print(mensagem)

print("-----------------------------------------------------------------------")

# print("Calculadora de Dobro!")
# Simulando alguém que digitou a palavra 'dez' em vez do número 10
# numero_digitado = "dez"
# dobro = int(numero_digitado) * 2
# print("O dobro é:", dobro)
print("Calculadora de Dobro!")
# Simulando alguém que digitou a palavra 'dez' em vez do número 10
numero_digitado = input("Digite um número inteiro: ")
while not numero_digitado.isdigit(): # Correção: foi adicionada uma validação para aceitar somente números inteiros.
    print("Valor inválido! Digite um número inteiro. Exemplo: 10")
    numero_digitado = input("Digite um número inteiro: ")
numero_digitado = int(numero_digitado)
dobro = numero_digitado * 2
print("O dobro é:", dobro)

print("-----------------------------------------------------------------------")

# cat_attributes = {
#    "name": "Zia",
#    "age": 1,
#    "color": "grey"
# }
# Tentando descobrir a raça (breed) da gata
# raca_gato = cat_attributes["breed"]
# print("A raça da gata é:", raca_gato)
cat_attributes = {
    "name": "Zia",
    "age": 1,
    "color": "grey",
    "breed": "Siamês" # Correção: foi adicionada a chave "breed" que não existia no dicionário.
}
# Tentando descobrir a raça (breed) da gata
raca_gato = cat_attributes["breed"]
print("A raça da gata é:", raca_gato)

print("-----------------------------------------------------------------------")

# some_numbers = [10, 20, 30]
# Tentando acessar o quarto número da lista
# quarto_numero = some_numbers[3]
# print("O número escolhido foi:", quarto_numero)
some_numbers = [10, 20, 30, 40] # Correção: foi adicionado o quarto elemento na lista para permitir o acesso ao índice 3.
# Tentando acessar o quarto número da lista
quarto_numero = some_numbers[3]
print("O número escolhido foi:", quarto_numero)

print("-----------------------------------------------------------------------")

# tesouro_moedas = 100
# aventureiros_sobreviventes = 0
# print("Calculando a divisão do tesouro...")
# moedas_por_pessoa = tesouro_moedas / aventureiros_sobreviventes
# print("Cada aventureiro vai receber:", moedas_por_pessoa)
tesouro_moedas = 100
aventureiros_sobreviventes = 0
print("Calculando a divisão do tesouro...")
if aventureiros_sobreviventes > 0: # Correção: foi adicionada uma condição para evitar a divisão por zero.
    moedas_por_pessoa = tesouro_moedas / aventureiros_sobreviventes
    print("Cada aventureiro vai receber:", moedas_por_pessoa)
else:
    print("Não há aventureiros sobreviventes para dividir o tesouro.")

print("-----------------------------------------------------------------------")

# print("=== Sistema do Zoológico ===")
# horário, alimento, quantidade
# dieta_axolote = ("08:00", "minhocas", 50)
# print("O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!")
# dieta_axolote[1] = "pizza de calabresa"
# print("Nova dieta:", dieta_axolote)
print("=== Sistema do Zoológico ===")
# horário, alimento, quantidade
dieta_axolote = ["08:00", "minhocas", 50] # Correção: a tupla foi alterada para lista, pois listas permitem a alteração dos elementos.
print("O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!")
dieta_axolote[1] = "pizza de calabresa"
print("Nova dieta:", dieta_axolote)

print("-----------------------------------------------------------------------")

# def contagem_regressiva(tempo):
#    print(f"Faltam {tempo} segundos...")
    # Passo Recursivo: A função chama a si mesma
#    contagem_regressiva(tempo - 1)
# print("Iniciando contagem para a explosão do Anel...")
# contagem_regressiva(3)
def contagem_regressiva(tempo):
    if tempo == 0: # Correção: foi adicionada uma condição de parada para evitar a recursão infinita.
        return
    print(f"Faltam {tempo} segundos...")
    # Passo Recursivo: A função chama a si mesma
    contagem_regressiva(tempo - 1)
print("Iniciando contagem para a explosão do Anel...")
contagem_regressiva(3)
# Out:
# O herói que vai salvar a cidade é o Batman
# -----------------------------------------------------------------------
# A idade do meu cachorro é 5 anos.
# -----------------------------------------------------------------------
# Calculadora de Dobro!
# Digite um número inteiro: dez
# Valor inválido! Digite um número inteiro. Exemplo: 10
# Digite um número inteiro: 10
# O dobro é: 20
# -----------------------------------------------------------------------
# A raça da gata é: Siamês
# -----------------------------------------------------------------------
# O número escolhido foi: 40
# -----------------------------------------------------------------------
# Calculando a divisão do tesouro...
# Não há aventureiros sobreviventes para dividir o tesouro.
# -----------------------------------------------------------------------
# === Sistema do Zoológico ===
# O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!
# Nova dieta: ['08:00', 'pizza de calabresa', 50]
# -----------------------------------------------------------------------
# Iniciando contagem para a explosão do Anel...
# Faltam 3 segundos...
# Faltam 2 segundos...
# Faltam 1 segundos...
