# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/aula06/isabella_lima_aula06_ex5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 06 | EXERCÍCIO 5 | Banco de Dados de Biblioteca (Combinação de Tipos)

# Objetivo:
# Imagine que sua biblioteca local peça a você para organizar o catálogo de livros
# em um dicionário Python. Neste exercício, vamos focar em estruturar e escolher
# os tipos de dados certos.

# 1. Crie uma estrutura combinada que armazene informações detalhadas sobre os livros.
# (Exemplo: O dicionário principal tem o nome do livro como chave, e o valor é outro
# dicionário contendo o nome do autor, ano de publicação, uma lista de gêneros
# literários e se ele está disponível ou emprestado)

# Estas são as informações que precisamos armazenar sobre cada livro:
# - Título
# - Nome do autor, ano de nascimento e nacionalidade
# - Número de páginas
# - Disponibilidade
# - Membro da biblioteca que o pegou emprestado atualmente
# - Ano de publicação
# - Gêneros
# - Avaliação (1-5)
biblioteca = {
    "Jane Eyre": {
        "autor": "Charlotte Brontë",
        "nascimento": 1816,
        "nacionalidade": "Britânica",
        "paginas": 659,
        "disponivel": True,
        "emprestado_para": None,
        "ano": 1847,
        "generos": ["Ficção Vitoriana", "Romance de Formação", "Histórico"],
        "avaliacao": 4.6
    },

    "Python Illustrated": {
        "autor": ["Zia van Putten", "Maaike van Putten", "Imke van Putten"],
        "nascimento": [2023, 1991, 1997],
        "nacionalidade": "Holandesa",
        "paginas": 432,
        "disponivel": False,
        "emprestado_para": "Isaque",
        "ano": 2026,
        "generos": ["Informativo", "Educação"],
        "avaliacao": 5
    },

    "Se os gatos desaparecessem do mundo": {
        "autor": "Genki Kawamura",
        "paginas": 144,
        "disponivel": False,
        "emprestado_para": "Cici",
        "ano": 2012,
        "generos": ["Ficção Literária", "Realismo Mágico", "Ficção Filosófica"],
        "avaliacao": 4.2
    },

    "O Iluminado": {
        "autor": "Stephen King",
        "nascimento": 1947,
        "nacionalidade": "Americana",
        "paginas": 464,
        "disponivel": True,
        "emprestado_para": None,
        "ano": 1977,
        "generos": ["Terror", "Suspense", "Sobrenatural"],
        "avaliacao": 4.5
    },

    "It: A Coisa": {
        "autor": "Stephen King",
        "nascimento": 1947,
        "nacionalidade": "Americana",
        "paginas": 1104,
        "disponivel": True,
        "emprestado_para": None,
        "ano": 1986,
        "generos": ["Terror", "Suspense", "Sobrenatural"],
        "avaliacao": 4.6
    },

    "Carrie": {
        "autor": "Stephen King",
        "nascimento": 1947,
        "nacionalidade": "Americana",
        "paginas": 200,
        "disponivel": True,
        "emprestado_para": None,
        "ano": 1974,
        "generos": ["Terror", "Ficção", "Sobrenatural"],
        "avaliacao": 4.1
    }
}

# Imprima uma lista de todos os títulos de livros que a biblioteca possui.
print("\nBANCO DE DADOS DA BIBLIOTECA")
print("\nLivros disponíveis no catálogo:")
for titulo in biblioteca:
    print("-", titulo)

# Verifique se "Romance" é um gênero de "Python Illustrated" e imprima a resposta.
print("\nGÊNERO DO LIVRO")
print("Romance é um gênero de Python Illustrated?",
      "Romance" in biblioteca["Python Illustrated"]["generos"])

# Imprima a nacionalidade do autor de Jane Eyre.
print("\nINFORMAÇÕES DO AUTOR")
print("Nacionalidade da autora de Jane Eyre:",
      biblioteca["Jane Eyre"]["nacionalidade"])

# Cici devolveu o livro que pegou emprestado.
# Atualize os valores de Se os gatos desaparecessem do mundo, de acordo.
biblioteca["Se os gatos desaparecessem do mundo"]["disponivel"] = True
biblioteca["Se os gatos desaparecessem do mundo"]["emprestado_para"] = None

print("\nDEVOLUÇÃO")
print("Se os gatos desaparecessem do mundo foi devolvido por Cici.")
print("Disponível:",
      biblioteca["Se os gatos desaparecessem do mundo"]["disponivel"])

# Verifique se Python Illustrated está disponível e imprima quem o pegou
# emprestado caso não esteja.
print("\nEMPRÉSTIMO")

if biblioteca["Python Illustrated"]["disponivel"]:
    print("Python Illustrated está disponível.")
else:
    print("Python Illustrated não está disponível.")
    print("Emprestado para:",
          biblioteca["Python Illustrated"]["emprestado_para"])
# Out:
# BANCO DE DADOS DA BIBLIOTECA
#
# Livros disponíveis no catálogo:
# - Jane Eyre
# - Python Illustrated
# - Se os gatos desaparecessem do mundo
# - O Iluminado
# - It: A Coisa
# - Carrie
#
# GÊNERO DO LIVRO
# Romance é um gênero de Python Illustrated? False
#
# INFORMAÇÕES DO AUTOR
# Nacionalidade da autora de Jane Eyre: Britânica
#
# DEVOLUÇÃO
# Se os gatos desaparecessem do mundo foi devolvido por Cici.
# Disponível: True
#
# EMPRÉSTIMO
# Python Illustrated não está disponível.
# Emprestado para: Isaque
