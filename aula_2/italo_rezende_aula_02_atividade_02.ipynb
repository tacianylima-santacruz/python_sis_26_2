# %% [markdown]
# <a href="https://colab.research.google.com/github/irezendegarcia-prog/python_sis_26_3_periodo/blob/Italo_Rezende/aula_2/italo_rezende_aula_02_atividade_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 02 - Atividade prática 02 - 12/08/2026

# %%
nome_piloto = input("Digite o seu nome: ")
tempo_competindo = input("Diga a quanto tempo você compete na F1: ")
velocidade_maxima = input("Qual a velocidade máxima que você já alcançou? ")
venceu_corrida = input("Você já venceu alguma corrida?")

# Exibindo a ficha do piloto de acordo com as informações cedidas
print (
    f"""
    Ficha do piloto:
    Nome: {nome_piloto}
    Tempo no campeonato: {tempo_competindo}
    Velocidade máxima alcançada: {velocidade_maxima}
    Já venceu alguma corrida: {venceu_corrida}
      """
)
# Out:
# Digite o seu nome: Italo
# Diga a quanto tempo você compete na F1: 5
# Qual a velocidade máxima que você já alcançou? 335
# Você já venceu alguma corrida?sim
#
#     Ficha do piloto: Nome: Italo
#     Tempo no campeonato: 5
#     Velocidade máxima alcançada: 335
#     Já venceu alguma corrida: sim
