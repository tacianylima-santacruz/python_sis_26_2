# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/isabella_lima_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Dean Winchester"
idade = 45
altura = 1.85
cacador = True

print(f"Nome: {nome}")
print(f"Idade: {idade}")
print(f"Altura: {altura:.2f} m")
print(f"É caçador? {cacador}")
# Out:
# Nome: Dean Winchester
# Idade: 45
# Altura: 1.85 m
# É caçador? True
