# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusMacagnan/AulaPythonFaculdade/blob/Matheus_Alves_Macagnan/Aula2/Matheus_Macagnan_aula_02_Atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***AULA 1***

# %% [markdown]
# Atividade Prática 01:

# %%
#Configurando o personagem do Personagem

nome_personagem = "Prooziim"          #É o nome que sera utilizado para identificar ele.
nivel_personagem = 20                 #Usado para saber seu nivel, e ver sua força/experiencia
forca_personagem = 31.5               #Usado para saber o dano do nosso guerreiro
armadura_equipada = False             #Esta quipando uma armadura? Se nao tiver, vai levar muito dano

#Criando um classe

class Prooziim:
  """Este personagem é um viajante de mundos, vive visitando e desvendando lugares
  para se aventurar e ganhar novas experiencias e xp para subir de nivel. """

help(Prooziim)
# Out:
# Help on class Prooziim in module __main__:
#
# class Prooziim(builtins.object)
#  |  Este personagem é um viajante de mundos, vive visitando e desvendando lugares
#  |  para se aventurar e ganhar novas experiencias e xp para subir de nivel.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
