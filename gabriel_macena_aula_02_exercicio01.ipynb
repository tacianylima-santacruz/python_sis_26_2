# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmacena0409/python_sis_26_2/blob/gabriel_macena/gabriel_macena_aula_02_exercicio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
personagem_nome = "sindrome"
personagem_nivel = 69
raio_precisao = 0.99
arma_equipada = True


print(type(personagem_nome),personagem_nome)
print(type(personagem_nivel),personagem_nivel)
print(type(raio_precisao),raio_precisao)
print(type(arma_equipada),arma_equipada)

personagem_peso = "79"
personagem_altura = "1,60"
personagem_cor_olhos = "azul"
personagem_cabelo = "preto"


print(type(personagem_peso),personagem_peso)
print(type(personagem_altura),personagem_altura)
print(type(personagem_cor_olhos),personagem_cor_olhos)
print(type(personagem_cabelo),personagem_cabelo)

class personagem:


      """


        Classe responsável por representar um personagem.

       Atributos:
          nome: Nome do personagem.
          nivel: Nível do personagem.
          precisao: Precisão do raio.
          arma_equipada: Indica se o personagem está com a arma equipada.

          peso: Peso do personagem em kg.
          altura: Altura do personagem em metros.
          cor_olhos: Cor dos olhos do personagem.
          cabelo: Cor do cabelo do personagem.


    """

help(personagem)
# Out:
# <class 'str'> sindrome
# <class 'int'> 69
# <class 'float'> 0.99
# <class 'bool'> True
# <class 'str'> 79
# <class 'str'> 1,60
# <class 'str'> azul
# <class 'str'> preto
# Help on class personagem in module __main__:
#
# class personagem(builtins.object)
#  |   Classe responsável por representar um personagem.
#  |
#  |  Atributos:
#  |     nome: Nome do personagem.
#  |     nivel: Nível do personagem.
#  |     precisao: Precisão do raio.
#  |     arma_equipada: Indica se o personagem está com a arma equipada.
#  |
#  |     peso: Peso do personagem em kg.
#  |     altura: Altura do personagem em metros.
#  |     cor_olhos: Cor dos olhos do personagem.
#  |     cabelo: Cor do cabelo do personagem.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
