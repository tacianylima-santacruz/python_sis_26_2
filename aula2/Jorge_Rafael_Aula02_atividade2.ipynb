# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelpimentacruz-stack/python_sis_26_2/blob/jorge_rafael/aula2/Jorge_Rafael_Aula02_atividade2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 02

# %%
#Criando dados do personagem
nick_name = input(" Digite o nome do Personagem: ")
especialidade = input(" Escolha a Especialidade: ")
perfil = input(" Escolha o Perfil: ")

print("Bem Vindo a missão:", nick_name)
print("Sua especialidade é:" , especialidade)
print("Seu perfil é:" , perfil)
# Out:
#  Digite o nome do Personagem: Jorge
#  Escolha a Especialidade: Fuzileiro
#  Escolha o Perfil: Sniper
# Bem Vindo a missão: Jorge
# Sua especialidade é: Fuzileiro
# Seu perfil é: Sniper
