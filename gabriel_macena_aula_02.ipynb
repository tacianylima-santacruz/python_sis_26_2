# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmacena0409/python_sis_26_2/blob/gabriel_macena/gabriel_macena_aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
personagem_nome = input("Digite o nome do personagem: ")
personagem_nivel = int(input("Digite o nível do personagem: "))
raio_precisao = float(input("Digite a precisão do raio: "))
arma_equipada = input("A arma está equipada? (True/False): ")

personagem_peso = float(input("Digite o peso: "))
personagem_altura = float(input("Digite a altura: "))
personagem_cor_olhos = input("Digite a cor dos olhos: ")
personagem_cabelo = input("Digite a cor do cabelo: ")


print("\n--- DADOS DO PERSONAGEM ---")

print(type(personagem_nome), personagem_nome)
print(type(personagem_nivel), personagem_nivel)
print(type(raio_precisao), raio_precisao)
print(type(arma_equipada), arma_equipada)

print("\n---------------------------")

print(type(personagem_peso), personagem_peso)
print(type(personagem_altura), personagem_altura)
print(type(personagem_cor_olhos), personagem_cor_olhos)
print(type(personagem_cabelo), personagem_cabelo)
# Out:
# Digite o nome do personagem: sindrome
# Digite o nível do personagem: 89
# Digite a precisão do raio: 67
# A arma está equipada? (True/False): true
# Digite o peso: 89
# Digite a altura: 1.88
# Digite a cor dos olhos: azul
# Digite a cor do cabelo: preto
#
# --- DADOS DO PERSONAGEM ---
# <class 'str'> sindrome
# <class 'int'> 89
# <class 'float'> 67.0
# <class 'str'> true
#
# ---------------------------
# <class 'float'> 89.0
# <class 'float'> 1.88
# <class 'str'> azul
# <class 'str'> preto
