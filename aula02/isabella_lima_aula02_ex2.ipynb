# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabella-de-Lima/python_sis_26_2/blob/isabella_lima/aula02/isabella_lima_aula02_ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 02 | EXERCÍCIO 2

# Introdução
print("========================================")
print("   SISTEMA DE CAÇADAS DOS WINCHESTER")
print("========================================")

print("\nUma nova ocorrência sobrenatural foi identificada.")
print("Os irmãos Winchester precisam investigar o caso.")
print("Antes de iniciar a caçada, registre os dados da missão.")

print("\n========================================")
print("        CADASTRO DA MISSÃO")
print("========================================")


# Cadastro dos dados da missão
cidade = input("\nDigite a cidade da missão: ")
quantidade_monstros = int(input("Digite a quantidade de monstros encontrados: "))
distancia = float(input("Digite a distância até o local em km: "))
missao_concluida = input("A missão foi concluída? (Sim/Não): ") == "Sim"


# Ficha da missão
print("\n========================================")
print("           FICHA DA MISSÃO")
print("========================================")

print("\nCidade: " + cidade)
print("Quantidade de monstros: " + str(quantidade_monstros))
print("Distância: " + str(distancia) + " km")
print("Missão concluída: " + str(missao_concluida))

print("\n========================================")
# Out:
# ...
#    SISTEMA DE CAÇADAS DOS WINCHESTER
# ...
#
# Uma nova ocorrência sobrenatural foi identificada.
# Os irmãos Winchester precisam investigar o caso.
# Antes de iniciar a caçada, registre os dados da missão.
#
# ...
#         CADASTRO DA MISSÃO
# ...
#
# Digite a cidade da missão: Lawrence, Kansas
# Digite a quantidade de monstros encontrados: 7
# Digite a distância até o local em km: 32.50
# A missão foi concluída? (Sim/Não): Sim
#
# ...
#            FICHA DA MISSÃO
# ...
#
# Cidade: Lawrence, Kansas
# Quantidade de monstros: 7
# Distância: 32.5 km
# Missão concluída: True
#
# ...
