# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-RFLopes/python_sis_26_2/blob/laura_lopes/aula02/laura_lopes_aula_02_exercicio_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite o seu nome: ")
print("Você acabou de subir de nivel!")
level_up = int(input("Digite o seu nivel: "))
nivel = level_up + 1
print("Seu novo nível é: ", nivel)
escolha_level = int(input( "Digite 1 para aprender bola de fogo ou 2 para aprender Canhão de Água: "))

vida_base = 30
mana_base =20
dano_base = 10

dano_fogo = 25+ nivel*3
dano_agua = 20 +nivel*3
custo_fogo=10
custo_agua=5
vida = vida_base + nivel*10
mana = mana_base + nivel*5
dano = dano_base + nivel*3

dano_feitico= 5

zombie_vida = 10 + nivel*3
zombie_dano = 15 + nivel*4

feitiços = ["Bola de Fogo", "Canhão de Água"]
danos_feiticos = [dano_fogo, dano_agua]
custo_feiticos = [custo_fogo, custo_agua]

feitiço_escolhido = feitiços[escolha_level - 1]
dano_magico = danos_feiticos[escolha_level - 1]

custo_magia = custo_feiticos[escolha_level - 1]
custos_ataques = [0, custo_magia]

ataques = ["Ataque físico", feitiço_escolhido]
danos_ataques = [dano, dano_magico]



print(f"\nParabens {nome}!")
print("Você ficou mais forte!!")
print("Vida: ",vida)
print("Mana: ",mana)
print("Dano: ",dano)
print("Você aprendeu:", feitiço_escolhido)

print("\n----------------------")
print("\nVamos testar a seu novo level com um inimigo!")
print("\nUm zombie aparece!")
print("Vida do zombie:", zombie_vida)
print("Sua vida:", vida)
print("Sua mana:", mana)

print("\n----------------------")
    # Ataque do zombie
vida -= zombie_dano
vida = max(vida, 0)

print("\nO zombie atacou!")
print("Dano recebido:", zombie_dano)
print("Sua vida:", vida)
print("\n----------------------")
escolha_ataque = int(input(
"\nEscolha seu ataque:\n"
"1 - Ataque físico\n"
"2 - " + feitiço_escolhido +
"\nEscolha: "
    ))

escolha_valida = escolha_ataque == 1 or mana >= custo_magia

escolha_ataque = escolha_ataque * escolha_valida + 1 * (not escolha_valida)

ataque_escolhido = ataques[escolha_ataque - 1]
dano_causado = danos_ataques[escolha_ataque - 1]
custo_ataque = custos_ataques[escolha_ataque - 1]


zombie_vida -= dano_causado
mana -= custo_ataque

zombie_vida = max(zombie_vida, 0)
mana = max(mana, 0)

print("\nVocê usou:", ataque_escolhido)
print("Dano causado:", dano_causado)
print("Mana gasta:", custo_ataque)
print("Vida do zombie:", zombie_vida)
print("Sua mana:", mana)




resultado = ["O zombie venceu!", "Você venceu!"]

vencedor = int(zombie_vida == 0)

print("\n----------------------")
print("      FIM DA BATALHA")

print(resultado[vencedor])
print("----------------------")
# Out:
# Digite o seu nome: Zoe
# Você acabou de subir de nivel!
# Digite o seu nivel: 3
# Seu novo nível é:  4
# Digite 1 para aprender bola de fogo ou 2 para aprender canhão de agua: 2
#
# Parabens Zoe!
# Você ficou mais forte!!
# Vida:  70
# Mana:  40
# Dano:  22
# Você aprendeu: Canhão de Água
#
# ----------------------
#
# Vamos testar a seu novo level com um inimigo!
#
# Um zombie aparece!
# Vida do zombie: 22
# Sua vida: 70
# Sua mana: 40
#
# Escolha seu ataque:
# 1 - Ataque físico
# 2 - Canhão de Água
# Escolha: 2
#
# Você usou: Canhão de Água
# Dano causado: 32
# Mana gasta: 5
# Vida do zombie: 0
# Sua mana: 35
#
# O zombie atacou!
# Dano recebido: 31
# Sua vida: 39
#
# ----------------------
#       FIM DA BATALHA
# Você venceu!
# ----------------------
