# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-RFLopes/python_sis_26_2/blob/laura_lopes/aula02/laura_lopes_aula_02_exercicio_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Kaladin:
    """ class(Kaladin)
    ordem corredor dos ventos
    espreno Syl(honra)
    """
    nome = "Kaladin"
    idade = 20
    altura = 1.80
    manipulador_fluxo = True



print(f'Nome: {Kaladin.nome}')
print(f'Idade: {Kaladin.idade}')
print(f'Altura: {Kaladin.altura}')
print(f'Manipuladorde fluxos? {Kaladin.manipulador_fluxo}')
# Out:
# Nome: Kaladin
# Idade: 20
# Altura: 1.8
# Manipuladorde fluxos? True

# %%
help(Kaladin)
# Out:
# Help on class Kaladin in module __main__:
#
# class Kaladin(builtins.object)
#  |  class(Kaladin)
#  |  ordem corredor dos ventos
#  |  espreno Syl(honra)
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  altura = 1.8
#  |
#  |  idade = 20
#  |
#  |  manipulador_fluxo = True
#  |
#  |  nome = 'Kaladin'

# %%
hero= input("Me diga o seu nome viajante!")
print("Olá! " + hero +" Como está?")
# Out:
# Me diga o seu nome viajante!Leia
# Olá! Leia Como está?
