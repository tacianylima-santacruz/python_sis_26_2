# %% [markdown]
# <a href="https://colab.research.google.com/github/brunokoskki/python_sis_26_2/blob/main/aula_02_bruno_firakoski.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aula 02
###Anteriormente, definíamos as variáveis do personagem de forma estática (fixa no código).
###Agora o sistema deve permitir o cadastro de dados de um personagem/usuário em variáveis (crie variáveis novas).
###E mostre a ficha do personagem/usuário.

# %%
##Criação de personagem:

print("Character creator:")

character_name = input("Type the character's name: ")
character_age = input("Type the character's age: ")
character_height = input("Type the character's height: ")

character_armor = input("""
Armor

[1] The character has armor
[0] The character has no armor

Your choice: """)

armor = bool(int(character_armor))

print(
    f"""
Name: {character_name}
Age: {character_age}
Height: {character_height}
Armor: {armor}
"""
)
# Out:
# Character creator:
# Type the character's name: aaa
# Type the character's age: 23
# Type the character's height: 23
#
# Armor
#
# [1] The character has armor
# [0] The character has no armor
#
# Your choice: 0
#
# Name: aaa
# Age: 23
# Height: 23
# Armor: True
