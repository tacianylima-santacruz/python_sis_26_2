# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusMacagnan/AulaPythonFaculdade/blob/Matheus_Alves_Macagnan/aula_07/Matheus_Macagnan_aula_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 1

# %%
nome_heroi = "Batman"

#O erro ocorre pois esta chamano a variavel errada no print
#print("O herói que vai salvar a cidade é o " + nome_heroi_cidade)

#Jeito correto chamando a variavel
print("O herói que vai salvar a cidade é o " + nome_heroi)
# Out:
# O herói que vai salvar a cidade é o Batman

# %%
idade_pet = 5

#aqui o erro ocorre pois no print esta tentando mostrar dois tipos de variaveis diferentes
#mensagem = "A idade do meu cachorro é "+ idade_pet +"anos."

# o correto é usar desta maneira
mensagem = f"A idade do meu cachorro é {idade_pet} anos."
print(mensagem)
# Out:
# A idade do meu cachorro é 5 anos.

# %%
print("Calculadora de Dobro")
#Simulando que digitou a palavra 'dez' em vez do número 10

#Desta maneira o sistema nao vai entender que é o número dez pois esta utilizando string
#numero_digitado = "dez"

#Jeito correto utilizando um int
numero_digitado = 10

dobro = numero_digitado * 2
print("O dobro do número digitado é:", dobro)
# Out:
# Calculadora de Dobro
# O dobro do número digitado é: 20

# %%
cat_attributes = {
    "name": "Zia",
    "age": 1,
    "color": "grey",
    "breed": "Siames"
}

# Tentando descobrir a raça (breed) da gata
raca_gato = cat_attributes["breed"]
print("A raça da gata é:", raca_gato)

#No codigo estava tentando buscar a raça sendo que nao existia
# Out:
# A raça da gata é: Siames

# %%
#Nesta lista nao possui o quarto numero, pois o index começa em 0
#some_numbers = [10, 20, 30]

#Agora conseguimos ver o quarto número
some_numbers = [10, 20, 30, 40]

# Tentando acessar o quarto número da lista
quarto_numero = some_numbers[3]
print("O número escolhido foi:", quarto_numero)
# Out:
# O número escolhido foi: 40

# %%
tesouro_moedas = 100
#Neste caso o computador nao aceita números dividos por zero, ele da erro
#aventureiros_sobreviventes = 0

aventureiros_sobreviventes = 2

print("Calculando a divisão do tesouro...")

moedas_por_pessoa = tesouro_moedas / aventureiros_sobreviventes

print("Cada aventureiro vai receber:", moedas_por_pessoa)
# Out:
# Calculando a divisão do tesouro...
# Cada aventureiro vai receber: 50.0

# %%
print("=== Sistema do Zoológico ===")
# horário, alimento, quantidade

dieta_axolote = ("08:00", "minhocas", 50)

print("Nova dieta:", dieta_axolote)

print("O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!")

#Nas tuplas não é possivel trocar o valor que foram definidas nela, neste caso
#Tem que alterar direto na tupla
#dieta_axolote[1] = "pizza de calabresa"

dieta_axolote = ("08:00", "Pizza", 50)

print("Nova dieta:", dieta_axolote)
# Out:
# === Sistema do Zoológico ===
# Nova dieta: ('08:00', 'minhocas', 50)
# O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!
# Nova dieta: ('08:00', 'Pizza', 50)

# %%
def contagem_regressiva(tempo):

#Colocando um if fazendo com que ele nao fique infinito
  if tempo <= 0:
    print("Bum!")
  else:
    print(f"Faltam {tempo} segundos...")

    # Passo Recursivo: A função chama a si mesma
    contagem_regressiva(tempo - 1)

print("Iniciando contagem para a explosão do Anel...")
contagem_regressiva(3)
# Out:
# Iniciando contagem para a explosão do Anel...
# Faltam 3 segundos...
# Faltam 2 segundos...
# Faltam 1 segundos...
# Bum!

# %% [markdown]
# Atividade 2 Parte 1

# %%
def nap_time(hours_list):
    total = 0
    counter = 1
    while counter < len(hours_list):
        total += hours_list[counter]
        counter += 1
    return total
cat_naps = [2, 3, 1.5, 4]
print("Total nap time:", nap_time(cat_naps))
# Out:
# Total nap time: 8.5

# %% [markdown]
# Codigo Parte 1 corrigido

# %%
def nap_time(hours_list):
    total = 0
    counter = 1
    while counter < len(hours_list):
        total += hours_list[counter]
        counter += 1
        #Utilizando o print do total para verificar o número que falta no calculo
        print(total)
    return total
cat_naps = [2, 3, 1.5, 4]
print("Total nap time:", nap_time(cat_naps))

#Para ter o resultado correto o certo seria ter o caunter = 0
# pois o caunter = 1 ele pula o primeiro indicie da lista começando
# no indicie 1 e não no primeiro que é 0
# Out:
# 3
# 4.5
# 8.5
# Total nap time: 8.5

# %% [markdown]
# Atividade 2 Parte 2

# %%
def average_meows(logs):
    total_meows_per_hour = 0

    for log in logs:
        nap_hours = 0

        for nap in log["naps"]:
            nap_hours += nap

        awake_hours = 24 - nap_hours
        total_meows_per_hour += log["meows"] / awake_hours

    return total_meows_per_hour / len(logs)

logs = [
    {"day": "Monday", "naps": [1, 2, 5], "meows": 90},
    {"day": "Tuesday", "naps": [4, 3, 2], "meows": 75},
    {"day": "Wednesday", "naps": [8, 6, 9, 1], "meows": 9},
    {"day": "Thursday", "naps": [1, 1, 5, 7], "meows": 38},
    {"day": "Friday", "naps": [3, 3, 2, 8], "meows": 94},
    {"day": "Saturday", "naps": [4, 8, 3], "meows": 64},
    {"day": "Sunday", "naps": [3, 3, 2, 8], "meows": 37}
]

print("Average meows per awake hour:", average_meows(logs))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_476/658020808.py in <cell line: 0>()
#      23 ]
#      24
# ---> 25 print("Average meows per awake hour:", average_meows(logs))
#      26
#
# /tmp/ipykernel_476/658020808.py in average_meows(logs)
#       9
#      10         awake_hours = 24 - nap_hours
# ---> 11         total_meows_per_hour += log["meows"] / awake_hours
#      12
#      13     return total_meows_per_hour / len(logs)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Codigo parte 2 Corrigido

# %%
def average_meows(logs):
    total_meows_per_hour = 0

    for log in logs:
        nap_hours = 0
        print(log)

        for nap in log["naps"]:
            nap_hours += nap
            print(nap_hours)

        awake_hours = 24 - nap_hours
        #Colocamos um if, para ver caso o gato tenha dormido 24 horas
        if awake_hours > 0:
          total_meows_per_hour += log["meows"] / awake_hours
        #Se ele dormiu 24h, ele nao divide e só soma os miados
        else:
          total_meows_per_hour += log["meows"]


    return total_meows_per_hour / len(logs)

logs = [
    {"day": "Monday", "naps": [1, 2, 5], "meows": 90},
    {"day": "Tuesday", "naps": [4, 3, 2], "meows": 75},
    {"day": "Wednesday", "naps": [8, 6, 9, 1], "meows": 9},
    {"day": "Thursday", "naps": [1, 1, 5, 7], "meows": 38},
    {"day": "Friday", "naps": [3, 3, 2, 8], "meows": 94},
    {"day": "Saturday", "naps": [4, 8, 3], "meows": 64},
    {"day": "Sunday", "naps": [3, 3, 2, 8], "meows": 37}
]

print("Average meows per awake hour:", average_meows(logs))
# Out:
# {'day': 'Monday', 'naps': [1, 2, 5], 'meows': 90}
# 1
# 3
# 8
# {'day': 'Tuesday', 'naps': [4, 3, 2], 'meows': 75}
# 4
# 7
# 9
# {'day': 'Wednesday', 'naps': [8, 6, 9, 1], 'meows': 9}
# 8
# 14
# 23
# 24
# {'day': 'Thursday', 'naps': [1, 1, 5, 7], 'meows': 38}
# 1
# 2
# 7
# 14
# {'day': 'Friday', 'naps': [3, 3, 2, 8], 'meows': 94}
# 3
# 6
# 8
# 16
# {'day': 'Saturday', 'naps': [4, 8, 3], 'meows': 64}
# 4
# 12
# 15
# {'day': 'Sunday', 'naps': [3, 3, 2, 8], 'meows': 37}
# 3
# 6
# 8
# 16
# Average meows per awake hour: 6.701587301587302

# %% [markdown]
# Atividade 2 Parte 3

# %%
def total_distance(*segments):
    total = 0
    for length, unit in segments:
        if unit.lower() == "M":
            total += length
        elif unit.lower() == "km":
            total += length / 1000

    print("Total distance:", total, "meters")

total_distance(
    (2.5, "km"),
    (400, "M"),
    (1.0, "km"),
    (800, "m"),
    (1.3, "KM"),
    (900, "m "),
    (1.1, "km")
)
# Out:
# Total distance: 0.005900000000000001 meters

# %% [markdown]
# Codigo Parte 3 Corrigido

# %%
def total_distance(*segments):
    total = 0
    for length, unit in segments:
        if unit.lower() == "M":
            total += length / 1000
        elif unit.lower() == "km":
            total += length
    Total_Metros = total * 1000

    print("Total distance:", Total_Metros, "meters")

total_distance(
    (2.5, "km"),
    (400, "M"),
    (1.0, "km"),
    (800, "M"),
    (1.3, "KM"),
    (900, "M"),
    (1.1, "km")
)
# Out:
# Total distance: 5900.0 meters

# %% [markdown]
# Atividade 3

# %%
def ticket_type():
    age = input("Enter your age: ")
    if age < 12:
        print("You get in for free. Lucky you!")
    elif age < 18:
        print("You get a youth discount!")
    elif age < 65:
        print("That's a full-price ticket for you.")
    else:
        print("You get a senior discount!")

ticket_type()
# Out:
# Enter your age: 19
# That's a full-price ticket for you.

# %% [markdown]
# Codigo Resolvido

# %%
from ast import Break
def ticket_type():
  while True:
      age = input("Enter your age: ")
      try:
        age = int(age)
        if age < 12:
          print("You get in for free. Lucky you!")
        elif age < 18:
          print("You get a youth discount!")
        elif age < 65:
          print("That's a full-price ticket for you.")
        else:
          print("You get a senior discount!")
        break

      except ValueError:
        print("Invalid input. Please enter a valid age.")


ticket_type()
# Out:
# Enter your age: a
# Invalid input. Please enter a valid age.
# Enter your age: 12
# You get a youth discount!
