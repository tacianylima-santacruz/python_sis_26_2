# %% [markdown]
# <a href="https://colab.research.google.com/github/vtbranco07-del/vt_python/blob/vitor_branco/vitor_branco_aula02-exercicio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
personagem_nome = "Geleia"
personagem_nivel = 67
barrigada_precisao = 0.99
arma_equipada = True




print(type(personagem_nome),personagem_nome)
print(type(personagem_nivel),personagem_nivel)
print(type(barrigada_precisao),barrigada_precisao)
print(type(arma_equipada),arma_equipada)

personagem_classe = "Gordinho"


print(type(personagem_classe),personagem_classe)

class personagem:


        """


Este código cria um personagem chamado Geleia e define
algumas de suas características, como nível, precisão,
arma equipada e classe.

Também utiliza a função type() para verificar o tipo
de cada variável.


        """
help(personagem)
# Out:
# <class 'str'> Geleia
# <class 'int'> 67
# <class 'float'> 0.99
# <class 'bool'> True
# <class 'str'> Gordinho
# Help on class personagem in module __main__:
#
# class personagem(builtins.object)
#  |          Este código cria um personagem chamado Geleia e define
#  |  algumas de suas características, como nível, precisão,
#  |  arma equipada e classe.
#  |
#  |  Também utiliza a função type() para verificar o tipo
#  |  de cada variável.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
