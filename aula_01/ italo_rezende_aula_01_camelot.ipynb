# %% [markdown]
# <a href="https://colab.research.google.com/github/irezendegarcia-prog/python_sis_26_3_periodo/blob/Italo_Rezende/aula_01/%20italo_rezende_aula_01_camelot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01 - Atividade Camelot

# %%
rei_arthur = 4
total_macas = rei_arthur * 12
print(total_macas)

cavaleiros = 5
total_macas_cavaleiros = int(total_macas / cavaleiros)
print('O total de maças por cavaleiros é: ', total_macas_cavaleiros)

portao_aberto = 8
print(portao_aberto < total_macas_cavaleiros,'= liberado')

adicional = cavaleiros + 1
resultado = adicional // total_macas
final = (resultado > portao_aberto)
print(final)

48
# Out:
# 48
# O total de maças por cavaleiros é:  9
# True = liberado
# False
# 48
