# %% [markdown]
# <a href="https://colab.research.google.com/github/tacianylima-santacruz/python_sis_26_2/blob/main/aula01/Jorge_Rafael_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula 1

# %%
from typing_extensions import final
rei_arthur = 4
Total_macas = rei_arthur * 12
print(Total_macas)

cavaleiros = 5
total_macas_cavaleiros = int(Total_macas / cavaleiros)
print("O total de macas por cavaleiros é: ",total_macas_cavaleiros)

portao_aberto = 8
print(portao_aberto < total_macas_cavaleiros, "liberado")

adicional = cavaleiros + 1
resultado = adicional // Total_macas
final=(resultado > portao_aberto)
print(final)
# Out:
# 48
# O total de macas por cavaleiros é:  9
# True liberado
# False
