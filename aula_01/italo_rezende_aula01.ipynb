# %% [markdown]
# <a href="https://colab.research.google.com/github/irezendegarcia-prog/python_sis_26_3_periodo/blob/Italo_Rezende/aula_01/italo_rezende_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Aula 01 | Atividade prática 01 - > Montando a ficha de um personagem

# %%
#Esta variável será utilizada para buscar o usuário no banco de dados da polícia
nome_personagem = str("Patrick Jane")
# Utilizada para comparação de desempenho físico
idade_personagem = int(39)
# Utilizada para registro
altura_personagem = float(1.75)
# Utilizado para verificar de o usuário possui posse de arma
possui_porte_arma = bool(False)


#Criando uma class
class PatrickJane:
    """
Este usuário possui alta inteligência, na qual utiliza para  a investigação
de homicídios e resolução de crimes. Não possui posse de arma, pois usa seus
dons mentalísticos para ler pessoas.
"""
help(PatrickJane)
# Out:
# Patrick Jane
# 39
# 1.75
# False
# Help on class NomePersonagem in module __main__:
#
# class NomePersonagem(builtins.object)
#  |  Este usuário possui alta inteligência, na qual utiliza para  a investigação
#  |  de homicídios e resolução de crime.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
