# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheus-200/python_sis_26_2/blob/Matheus_Gabriel_tava/aula_01/Matheus_Gabriel_aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("olá, qual o seu nome ? ")
idade = int(input("qual a sua idade ? "))

print ('Olá {} e sua idade é {}'.format(nome, idade))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1277/458559312.py in <cell line: 0>()
# ----> 1 nome = input("olá, qual o seu nome ? ")
#       2 idade = int(input("qual a sua idade ? "))
#       3
#       4 print ('Olá {} e sua idade é {}'.format(nome, idade))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
rei_arthur = 4
Total_macas = rei_arthur * 12
print(Total_macas)

cavaleiros = 5
total_macas_cavaleiros = int(Total_macas / cavaleiros)
print('O total de maças por cavaleiros é: ', total_macas_cavaleiros)

portao_aberto = 8
print(portao_aberto < total_macas_cavaleiros,'= liberado')

adicional = cavaleiros + 1
resultado = adicional // Total_macas
final = (resultado > portao_aberto)
print(final)

# %% [markdown]
# # Nova seção

# %% [markdown]
# # **ATV 01 - Montando a ficha de um personagem**

# %%
#CRIE 4 VARIÁVEIS UTILIZANDO OS 4 TIPOS DE DADOS:

nome = str('Matheus gabriel tavares da silva')
idade = int('22')
tamanho = float(1.75)
armadura = bool(True)

#print(f'{nome} - {idade} - {tamanho} - {armadura}')
