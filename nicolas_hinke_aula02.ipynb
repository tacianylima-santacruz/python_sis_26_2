# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasHinke/python_sis_26_2/blob/Nicolas_Hinke_num/nicolas_hinke_aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nome que será usado para identificar o personagem
personagem_nome = "Kratos"

# Nível que será usado para indicar a experiência do personagem
personagem_nivel = 15

# Altura que será usada para informar a altura do personagem
altura = 1.85

# Indica se o personagem está com uma arma equipada
arma_equipada = True


class Kratos:
    """Classificação do personagem como guerreiro."""

help(Kratos)
# Out:
# Help on class Kratos in module __main__:
#
# class Kratos(builtins.object)
#  |  Classificação do personagem como guerreiro.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
print(type(personagem_nome), personagem_nome)
print(type(personagem_nivel), personagem_nivel)
print(type(altura), altura)
print(type(arma_equipada), arma_equipada)
# Out:
# <class 'str'> Kratos
# <class 'int'> 15
# <class 'float'> 1.85
# <class 'bool'> True
